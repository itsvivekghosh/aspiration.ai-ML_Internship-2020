# %% [markdown]
# # Module 6 Week 7

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import warnings
plt.style.use("ggplot")
pd.set_option("display.max_columns", None)
sns.set(rc={'figure.figsize':(20, 10)}) ## Setting Figure Sizes as 20, 10
warnings.filterwarnings('ignore')
# %matplotlib notebook

# %% [markdown]
# ## Problem 6.1
# Create a table/data frame with the closing prices of 30 different stocks, with 10 from each of the caps

# %% [markdown]
# ### Small Caps

# %%
df = pd.read_csv('Datasets Used/Small_Cap/ASHOKA.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data = pd.DataFrame(df['Close Price'],df.index)
df_data.columns = ['Ashoka']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/ITDC.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['IDTC']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/PVR.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['PVR']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/RAYMOND.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Raymond']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/RCOM.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Rcom']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/SUZLON.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Suzlon']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/VENKEYS.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Venkeys']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/FORTIS.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Fortis']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/BOMDYEING.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Bombay Dyeing']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Small_Cap/BAJAJELEC.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Bajaj Elec']  = df['Close Price']

# %% [markdown]
# ### Mid Caps

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/ADANIPOWER.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Adani Power']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/RELINFRA.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Rel Infra']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/MUTHOOTFIN.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Muthoot Fin']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/MINDTREE.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Mind Tree']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/JINDALSTEL.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Jindal Steel']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/GODREJIND.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Godrej Ind']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/DHFL.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['DHFL']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/APOLLOTYRE.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Apollo Tyre']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/TATACHEM.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Tata Chem']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Mid_Cap/TATAPOWER.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Tata Power']  = df['Close Price']

# %% [markdown]
# ### Large Caps

# %%
df = pd.read_csv('Datasets Used/Large_Cap/ADANIPORTS.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Adani Ports']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/TITAN.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Titan']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/M&M.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['TCS']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/RELIANCE.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Reliance']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/LT.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['LT']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/ITC.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['ITC']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/HINDUNILVR.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Hind Unilvr']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/HINDALCO.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Hindalco']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/GAIL.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Gail']  = df['Close Price']

# %%
df = pd.read_csv('Datasets Used/Large_Cap/ASIANPAINT.csv')
df['Date'] = df['Date'].astype('datetime64')
df = df[df.Series == 'EQ']
df.set_index('Date',inplace = True)
df_data['Asian Paint']  = df['Close Price']

# %%
del(df)
df_data.head()
# Out:
#             Ashoka    IDTC      PVR  Raymond   Rcom  Suzlon  Venkeys  Fortis  \
# Date
# 2017-05-15  216.05  650.15  1524.95   772.80  32.00    19.6  1169.70  205.25
# 2017-05-16  214.90  636.70  1539.00   785.00  32.10    19.7  1177.00  207.90
# 2017-05-17  217.00  626.75  1530.30   783.65  31.95    19.9  1188.00  205.90
# 2017-05-18  209.65  604.65  1515.05   746.95  31.05    20.0  1156.90  196.85
# 2017-05-19  206.25  594.30  1513.55   723.10  30.55    20.6  1161.65  203.55
#
#             Bombay Dyeing  Bajaj Elec  Adani Power  Rel Infra  Muthoot Fin  \
# Date
# 2017-05-15          82.20      341.15        30.25     605.40       392.45
# 2017-05-16          83.40      347.00        32.85     611.05       394.80
# 2017-05-17          82.25      349.85        33.10     605.25       395.15
# 2017-05-18          78.95      334.10        31.90     578.65       379.20
# 2017-05-19          77.15      336.20        32.40     569.55       379.15
#
#             Mind Tree  Jindal Steel  Godrej Ind    DHFL  Apollo Tyre  \
# Date
# 2017-05-15     509.45        114.20      578.55  431.40       231.90
# 2017-05-16     511.30        114.10      584.80  424.45       234.40
# 2017-05-17     506.35        116.40      588.60  429.00       237.35
# 2017-05-18     492.90        113.30      574.60  417.95       232.65
# 2017-05-19     497.50        112.15      578.00  404.20       234.65
#
#             Tata Chem  Tata Power  Adani Ports   Titan      TCS  Reliance  \
# Date
# 2017-05-15     629.80       83.55       356.20  483.65  1375.65   1344.10
# 2017-05-16     643.90       83.85       354.50  488.30  1366.35   1356.30
# 2017-05-17     638.10       85.35       348.55  481.75  1378.80   1353.10
# 2017-05-18     624.90       83.75       347.90  471.65  1352.85   1327.35
# 2017-05-19     616.45       84.15       349.45  471.15  1333.40   1318.85
#
#                  LT     ITC  Hind Unilvr  Hindalco    Gail  Asian Paint
# Date
# 2017-05-15  1742.40  277.95       983.25    198.45  414.00      1148.05
# 2017-05-16  1740.70  283.45      1000.40    196.50  411.40      1142.85
# 2017-05-17  1755.45  281.65      1009.40    198.85  408.30      1154.95
# 2017-05-18  1722.60  277.90       990.25    194.00  404.75      1151.35
# 2017-05-19  1724.55  286.20      1008.00    191.00  401.05      1123.15

# %% [markdown]
# ## Problem 6.2
# Calculate average annual percentage return and volatility of all 30 stocks over a theoretical one year period

# %%
df_data = df_data.pct_change() * 100

daily_mean = df_data.mean()
daily_std = df_data.std()

annual_mean_return = round(daily_mean*252, 2)
annual_std = round(daily_std*np.sqrt(252), 2)

# %%
data = pd.DataFrame({'Mean' : annual_mean_return.values,
                    'Std Deviation' :annual_std})
data.reset_index(inplace =True)
data = data.rename(columns ={'index':'Stock'})
data
# Out:
#             Stock   Mean  Std Deviation
# 0          Ashoka -20.85          44.30
# 1            IDTC -36.94          52.78
# 2             PVR  11.11          31.02
# 3         Raymond   7.00          36.38
# 4            Rcom -88.17          98.54
# 5          Suzlon -46.82          59.36
# 6         Venkeys  38.17          62.74
# 7          Fortis -14.60          42.13
# 8   Bombay Dyeing  43.16          68.17
# 9      Bajaj Elec  31.61          40.24
# 10    Adani Power  30.53          61.05
# 11      Rel Infra -75.01          54.76
# 12    Muthoot Fin  23.30          35.72
# 13      Mind Tree  39.26          34.15
# 14   Jindal Steel  27.54          49.30
# 15     Godrej Ind  -9.03          26.66
# 16           DHFL -44.96          66.29
# 17    Apollo Tyre  -6.43          31.04
# 18      Tata Chem  -1.74          24.19
# 19     Tata Power -10.06          30.86
# 20    Adani Ports   6.05          30.98
# 21          Titan  49.16          32.48
# 22            TCS -27.24          44.06
# 23       Reliance   8.73          43.92
# 24             LT  -8.59          31.43
# 25            ITC   4.59          22.49
# 26    Hind Unilvr  29.94          19.40
# 27       Hindalco   4.03          33.68
# 28           Gail  -5.26          33.84
# 29    Asian Paint   9.80          20.95

# %% [markdown]
# ## Problem 6.3
# Cluster the 30 stocks according to their mean annual Volatilities and Returns using K-means clustering. Identify the optimum number of clusters using the Elbow curve method

# %%
X = data.iloc[:, 1:].values
name = data.iloc[:, 0]
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++',max_iter = 300,
                    n_init = 10,random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
plt.figure(figsize=(10, 6))
plt.plot(range(1,11), wcss, label = 'WCSS from 1 to 10')
plt.title("Elbow Method Graph", fontsize=18)
plt.xlabel("No of clusters",  fontsize=15)
plt.ylabel("WCSS", fontsize=15)
plt.legend()
plt.show()
# Out:
# <div id='616a7186-c94d-497b-b10a-f7d2c2404199'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-6249c63ace8f> in <module>
#      11
#      12 plt.figure(figsize=(10, 6))
# ---> 13 plt.plot(range(1,11), wcss, label = 'WCSS from 1 to 10', line='--')
#      14 plt.title("Elbow Method Graph", fontsize=18)
#      15 plt.xlabel("No of clusters",  fontsize=15)
#
# F:\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# F:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# F:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# F:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# F:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# F:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     253         default_dict = self._getdefaults(set(), kw)
#     254         self._setdefaults(default_dict, kw)
# --> 255         seg = mlines.Line2D(x, y, **kw)
#     256         return seg
#     257
#
# F:\Anaconda\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398         # update kwargs before updating data to give the caller a
#     399         # chance to init axes (and hence unit support)
# --> 400         self.update(kwargs)
#     401         self.pickradius = pickradius
#     402         self.ind_offset = 0
#
# F:\Anaconda\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# F:\Anaconda\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# F:\Anaconda\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Line2D' object has no property 'line'

# %%
print("So the optimum number of clusters is 3")
# Out:
# So the optimum number of clusters is 3

# %%
kmeans = KMeans(n_clusters = 3,init='k-means++',max_iter=300,
                    n_init = 10,random_state=0)
y_kmeans = kmeans.fit_predict(X)

plt.figure(figsize = (10, 6))
plt.scatter(X[y_kmeans==0,0],X[y_kmeans==0,1],s = 100
            , c = 'red',label = 'Cluster 1')

plt.scatter(X[y_kmeans==1,0],X[y_kmeans==1,1],s = 100
            , c = 'blue',label = 'Cluster 2')
 

plt.scatter(X[y_kmeans==2,0],X[y_kmeans==2,1],s = 100
            , c = 'black',label = 'Cluster 3')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],
            s = 100,c = 'yellow',label = "Centeroid")


for i, txt in enumerate(name):
    plt.annotate(txt, (X[i,0], X[i,1]))

plt.title("Cluster of Stocks")
plt.xlabel("Mean")
plt.ylabel("Std Deviation")
plt.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Problem 6.4
# Prepare a separate Data frame to show which stocks belong to the same cluster

# %%
cluster_1 = name[y_kmeans==0]
cluster_1 = list(cluster_1)
cluster_1
# Out:
# ['Venkeys',
#  'Bombay Dyeing',
#  'Bajaj Elec',
#  'Adani Power',
#  'Muthoot Fin',
#  'Mind Tree',
#  'Jindal Steel',
#  'Titan',
#  'Hind Unilvr']

# %%
cluster_2 = name[y_kmeans==1]
cluster_2 = list(cluster_2)
cluster_2
# Out:
# ['IDTC', 'Rcom', 'Suzlon', 'Rel Infra', 'DHFL']

# %%
cluster_3 = name[y_kmeans==2]
cluster_3 = list(cluster_3)
cluster_3
# Out:
# ['Ashoka',
#  'PVR',
#  'Raymond',
#  'Fortis',
#  'Godrej Ind',
#  'Apollo Tyre',
#  'Tata Chem',
#  'Tata Power',
#  'Adani Ports',
#  'TCS',
#  'Reliance',
#  'LT',
#  'ITC',
#  'Hindalco',
#  'Gail',
#  'Asian Paint']

# %%
cluster = pd.DataFrame({"Cluster 1" : 'No',"Cluster 2" : 'No',"Cluster 3" : 'No'},data['Stock'])

# %%
for i in range(len(data['Stock'])):
    
    if data['Stock'][i] in cluster_1:
        cluster['Cluster 1'][i] = 'Yes'
        
    if data['Stock'][i] in cluster_2:
        cluster['Cluster 2'][i] = 'Yes'
        
    if data['Stock'][i] in cluster_3:
        cluster['Cluster 3'][i] = 'Yes'

# %%
cluster
# Out:
#               Cluster 1 Cluster 2 Cluster 3
# Stock
# Ashoka               No        No       Yes
# IDTC                 No       Yes        No
# PVR                  No        No       Yes
# Raymond              No        No       Yes
# Rcom                 No       Yes        No
# Suzlon               No       Yes        No
# Venkeys             Yes        No        No
# Fortis               No        No       Yes
# Bombay Dyeing       Yes        No        No
# Bajaj Elec          Yes        No        No
# Adani Power         Yes        No        No
# Rel Infra            No       Yes        No
# Muthoot Fin         Yes        No        No
# Mind Tree           Yes        No        No
# Jindal Steel        Yes        No        No
# Godrej Ind           No        No       Yes
# DHFL                 No       Yes        No
# Apollo Tyre          No        No       Yes
# Tata Chem            No        No       Yes
# Tata Power           No        No       Yes
# Adani Ports          No        No       Yes
# Titan               Yes        No        No
# TCS                  No        No       Yes
# Reliance             No        No       Yes
# LT                   No        No       Yes
# ITC                  No        No       Yes
# Hind Unilvr         Yes        No        No
# Hindalco             No        No       Yes
# Gail                 No        No       Yes
# Asian Paint          No        No       Yes
